# %%
import pandas as pd
import xgboost as xgb
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.mixture import GaussianMixture
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, ConcatDataset

# %%
file_path = './data./Data Set for Chapter - Sheet1.csv'
df = pd.read_csv(file_path)
df = df.drop('S.no',axis = 1)
df = df.dropna()
df
# Out:
#       Age  Intimate Partners  \
# 0    45.0                  4
# 1    43.0                  4
# 2    39.0                  5
# 3    35.0                  5
# 4    32.0                  1
# ..    ...                ...
# 540  36.0                  2
# 541  45.0                  4
# 542  43.0                  4
# 543  39.0                  5
# 544  35.0                  5
#
#      Protection Usage (0: Never, 1: Sometimes, 2: Always)  Symptoms  Location  \
# 0                                                    0            0         2
# 1                                                    0            0         2
# 2                                                    0            0         3
# 3                                                    2            0         3
# 4                                                    1            1         2
# ..                                                 ...          ...       ...
# 540                                                  0            1         2
# 541                                                  0            0         2
# 542                                                  0            0         3
# 543                                                  0            0         3
# 544                                                  2            0         1
#
#      Education  STD Testing history (0: No, 1: Yes)  STD Status
# 0            1                                    1           1
# 1            1                                    1           1
# 2            1                                    1           1
# 3            1                                    0           1
# 4            1                                    0           0
# ..         ...                                  ...         ...
# 540          0                                    1           1
# 541          0                                    1           1
# 542          0                                    0           0
# 543          0                                    0           0
# 544          0                                    1           1
#
# [544 rows x 8 columns]

# %%
train_df,test_df = train_test_split(df,test_size=0.2,random_state=42)

# %%
## Training Autoencoder Model

X = df.drop('STD Status',axis = 1)
y = df['STD Status']

X_scaled = MinMaxScaler().fit_transform(X)

X_infected = X_scaled[y==1]
X_uninfected = X_scaled[y==0]

class Autoencoder(nn.Module):
  def __init__(self):
    super(Autoencoder,self).__init__()
    self.encoder = nn.Sequential(
        nn.Linear(7,5),
        nn.Tanh(),
        nn.Linear(5,3),
    )
    self.decoder = nn.Sequential(
        nn.Linear(3,5),
        nn.Tanh(),
        nn.Linear(5,7),
        nn.ReLU()
    )
  def forward(self,x):
    x = self.encoder(x)
    x = self.decoder(x)
    return x

autoencoder = Autoencoder()

criterion = nn.MSELoss()
optimizer = optim.Adadelta(autoencoder.parameters())

batch_size = 16
epochs = 30

X_infected_tensor = torch.FloatTensor(X_infected)
X_uninfected_tensor = torch.FloatTensor(X_uninfected)

infected_dataset = TensorDataset(X_infected_tensor,X_infected_tensor)
uninfected_dataset = TensorDataset(X_uninfected_tensor,X_uninfected_tensor)

dataset = ConcatDataset([infected_dataset,uninfected_dataset])
loader = DataLoader(dataset,batch_size=batch_size,shuffle=True)
infected_loader = DataLoader(infected_dataset,batch_size=batch_size,shuffle=True)
uninfected_loader = DataLoader(uninfected_dataset,batch_size=batch_size,shuffle=True)
losses = []

for epoch in range(epochs):
  for data in loader:
    inputs,targets = data
    optimizer.zero_grad()
    outputs = autoencoder(inputs)
    loss = criterion(outputs,targets)
    loss.backward()
    optimizer.step()
    losses.append(loss.detach().numpy())


losses[-100:]
# Out:
# [array(0.05448578, dtype=float32),
#  array(0.07968129, dtype=float32),
#  array(0.06443986, dtype=float32),
#  array(0.06701566, dtype=float32),
#  array(0.05061757, dtype=float32),
#  array(0.07657838, dtype=float32),
#  array(0.07714188, dtype=float32),
#  array(0.07496406, dtype=float32),
#  array(0.05469698, dtype=float32),
#  array(0.06153443, dtype=float32),
#  array(0.08868213, dtype=float32),
#  array(0.07938512, dtype=float32),
#  array(0.09604077, dtype=float32),
#  array(0.05290859, dtype=float32),
#  array(0.09426009, dtype=float32),
#  array(0.05382857, dtype=float32),
#  array(0.04247431, dtype=float32),
#  array(0.07982804, dtype=float32),
#  array(0.05812027, dtype=float32),
#  array(0.05419628, dtype=float32),
#  array(0.06677362, dtype=float32),
#  array(0.04367984, dtype=float32),
#  array(0.05307752, dtype=float32),
#  array(0.07378739, dtype=float32),
#  array(0.07863349, dtype=float32),
#  array(0.08956944, dtype=float32),
#  array(0.10256601, dtype=float32),
#  array(0.06550241, dtype=float32),
#  array(0.08339465, dtype=float32),
#  array(0.06482792, dtype=float32),
#  array(0.08483502, dtype=float32),
#  array(0.06954867, dtype=float32),
#  array(0.05277615, dtype=float32),
#  array(0.07366303, dtype=float32),
#  array(0.05898345, dtype=float32),
#  array(0.05392649, dtype=float32),
#  array(0.08011723, dtype=float32),
#  array(0.09241015, dtype=float32),
#  array(0.0597697, dtype=float32),
#  array(0.06018842, dtype=float32),
#  array(0.07727436, dtype=float32),
#  array(0.06654229, dtype=float32),
#  array(0.0865278, dtype=float32),
#  array(0.05759034, dtype=float32),
#  array(0.07567341, dtype=float32),
#  array(0.03977918, dtype=float32),
#  array(0.05765472, dtype=float32),
#  array(0.08850742, dtype=float32),
#  array(0.06126372, dtype=float32),
#  array(0.05678954, dtype=float32),
#  array(0.04708881, dtype=float32),
#  array(0.09160934, dtype=float32),
#  array(0.08336774, dtype=float32),
#  array(0.07681389, dtype=float32),
#  array(0.08257078, dtype=float32),
#  array(0.05564584, dtype=float32),
#  array(0.09155194, dtype=float32),
#  array(0.05925282, dtype=float32),
#  array(0.09784092, dtype=float32),
#  array(0.08065854, dtype=float32),
#  array(0.07222684, dtype=float32),
#  array(0.06518157, dtype=float32),
#  array(0.05479736, dtype=float32),
#  array(0.06677792, dtype=float32),
#  array(0.05951528, dtype=float32),
#  array(0.08920397, dtype=float32),
#  array(0.06143429, dtype=float32),
#  array(0.0503285, dtype=float32),
#  array(0.07183843, dtype=float32),
#  array(0.07585572, dtype=float32),
#  array(0.07935683, dtype=float32),
#  array(0.06284641, dtype=float32),
#  array(0.04025762, dtype=float32),
#  array(0.06264932, dtype=float32),
#  array(0.06279044, dtype=float32),
#  array(0.05847821, dtype=float32),
#  array(0.07229018, dtype=float32),
#  array(0.06643628, dtype=float32),
#  array(0.05467501, dtype=float32),
#  array(0.1070238, dtype=float32),
#  array(0.09078479, dtype=float32),
#  array(0.0866294, dtype=float32),
#  array(0.08122294, dtype=float32),
#  array(0.10211397, dtype=float32),
#  array(0.05050813, dtype=float32),
#  array(0.06391414, dtype=float32),
#  array(0.08093127, dtype=float32),
#  array(0.06434619, dtype=float32),
#  array(0.06929646, dtype=float32),
#  array(0.04477436, dtype=float32),
#  array(0.05351257, dtype=float32),
#  array(0.08046084, dtype=float32),
#  array(0.07595003, dtype=float32),
#  array(0.06244948, dtype=float32),
#  array(0.05662664, dtype=float32),
#  array(0.10229421, dtype=float32),
#  array(0.0433597, dtype=float32),
#  array(0.05062209, dtype=float32),
#  array(0.08975341, dtype=float32),
#  array(0.07855064, dtype=float32)]

# %%
def encoded(model,data_loader):
  hidden_rep = []
  with torch.no_grad():
    for data in data_loader:
      inputs,_=data
      hidden = model.encoder(inputs)
      hidden_rep.append(hidden)
  return torch.cat(hidden_rep,dim=0)

infected_encoded = encoded(autoencoder,infected_loader)
uninfected_encoded = encoded(autoencoder,uninfected_loader)

encoded_X = torch.cat([infected_encoded,uninfected_encoded],dim=0).numpy()
y_infected = np.ones(infected_encoded.shape[0])
y_uninfected = np.zeros(uninfected_encoded.shape[0])
encoded_y = np.append(y_infected,y_uninfected)

X_train,X_test,y_train,y_test = train_test_split(encoded_X,encoded_y,test_size=0.2)

# %%
gmm = GaussianMixture(n_components=2,random_state=42)
gmm.fit(X_train)
y_pred=gmm.predict(X_test)

conf_matrix = confusion_matrix(y_test,y_pred)
report = classification_report(y_test,y_pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.84      0.88        51
#          1.0       0.87      0.93      0.90        58
#
#     accuracy                           0.89       109
#    macro avg       0.89      0.89      0.89       109
# weighted avg       0.89      0.89      0.89       109

# %%
rows_with_nan = df[df.isna().any(axis=1)]
rows_with_nan
# Out:
# Empty DataFrame
# Columns: [Age, Intimate Partners, Protection Usage (0: Never, 1: Sometimes, 2: Always), Symptoms, Location, Education, STD Testing history (0: No, 1: Yes), STD Status]
# Index: []

# %%
#implementing xgboost
X_train, X_test, y_train, y_test = train_test_split(encoded_X,encoded_y,test_size=0.3,random_state=41) # 70% training and 30% test
X_cv,y_cv = X_test[:int(len(X_test)/2)],y_test[:int(len(y_test)/2)]
X_test,y_test = X_test[int(len(X_test)/2):],y_test[int(len(y_test)/2):]

# %%
xgb_clf = xgb.XGBClassifier(
    objective="binary:logistic",
    eta=0.1,
    max_depth=5,
    min_child_weight=5,
    subsample=0.8,
    colsample_bytree=0.9
)

# Create classification matrices
dtrain_clf = xgb.DMatrix(X_train, y_train, enable_categorical=True)
dtest_clf = xgb.DMatrix(X_test, y_test, enable_categorical=True)
param_grid = { 'eta': [0.01, 0.1, 0.2,0.5],
               'max_depth': [3, 5, 7, 9, 11, 15, 20],
               'min_child_weight': [1,3,5,7,10],
               'subsample': [0.7,0.8, 0.9],
               'colsample_bytree': [0.7,0.8, 0.9]
             }

# %%
random_search_xgboost_model = RandomizedSearchCV(
    xgb_clf, param_grid, cv=5, scoring='neg_log_loss', n_iter=100, verbose=1
)
# Fit the model on the training data
random_search_xgboost_model.fit(X_train, y_train)

# Display the best hyperparameters
print("Best Hyperparameters:", random_search_xgboost_model.best_params_)

# Get the best model
best_random_search_xgb_model = random_search_xgboost_model.best_estimator_

# Evaluate the model with additional metrics
random_predictions = best_random_search_xgb_model.predict(X_cv)
print("Accuracy:", accuracy_score(y_cv, random_predictions))
print("Precision:", precision_score(y_cv, random_predictions))
print("Recall:", recall_score(y_cv, random_predictions))
report = classification_report(y_cv,random_predictions)
print(report)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Best Hyperparameters: {'subsample': 0.9, 'min_child_weight': 5, 'max_depth': 20, 'eta': 0.1, 'colsample_bytree': 0.9}
# Accuracy: 0.8780487804878049
# Precision: 0.9142857142857143
# Recall: 0.8205128205128205
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.93      0.89        43
#          1.0       0.91      0.82      0.86        39
#
#     accuracy                           0.88        82
#    macro avg       0.88      0.88      0.88        82
# weighted avg       0.88      0.88      0.88        82

# %%
best_params = random_search_xgboost_model.best_params_

# Re-run XGBoost CV with early stopping and additional metrics
xgb_random_search_tuned_results = xgb.cv(
    best_params, dtrain_clf,
    num_boost_round=1000,
    nfold=3,
    early_stopping_rounds=10,
    metrics=["auc", "error", "logloss"],
    verbose_eval=True
)

# Display tuned results
print("Tuned Results:")
print(xgb_random_search_tuned_results.iloc[-1])
# Out:
# [0]	train-auc:0.93934+0.00719	train-error:0.22868+0.14456	train-logloss:0.62739+0.00570	test-auc:0.91724+0.03391	test-error:0.26382+0.18056	test-logloss:0.63770+0.01114
# [1]	train-auc:0.95160+0.01100	train-error:0.12499+0.00648	train-logloss:0.57530+0.00826	test-auc:0.92349+0.02964	test-error:0.15806+0.04930	test-logloss:0.58984+0.01266
# [2]	train-auc:0.95612+0.01052	train-error:0.10791+0.01003	train-logloss:0.52982+0.00994	test-auc:0.92418+0.02572	test-error:0.14486+0.03604	test-logloss:0.54859+0.01397
# [3]	train-auc:0.96245+0.00845	train-error:0.10398+0.01849	train-logloss:0.49120+0.01185	test-auc:0.91868+0.02531	test-error:0.13959+0.03598	test-logloss:0.51574+0.01640
# [4]	train-auc:0.97168+0.00560	train-error:0.09345+0.01318	train-logloss:0.45528+0.01305	test-auc:0.91911+0.02137	test-error:0.13163+0.02102	test-logloss:0.48814+0.01765
# [5]	train-auc:0.97435+0.00481	train-error:0.09345+0.01669	train-logloss:0.42586+0.01435	test-auc:0.92006+0.01823	test-error:0.13165+0.02718	test-logloss:0.46528+0.01862
# [6]	train-auc:0.97711+0.00416	train-error:0.08818+0.00999	train-logloss:0.39939+0.01378	test-auc:0.92452+0.01472	test-error:0.12638+0.01977	test-logloss:0.44646+0.01724
# [7]	train-auc:0.97820+0.00311	train-error:0.08686+0.01176	train-logloss:0.37692+0.01437	test-auc:0.92602+0.01879	test-error:0.12378+0.02492	test-logloss:0.43217+0.01682
# [8]	train-auc:0.97923+0.00298	train-error:0.08686+0.01176	train-logloss:0.35561+0.01503	test-auc:0.92453+0.01843	test-error:0.12113+0.02122	test-logloss:0.41649+0.01845
# [9]	train-auc:0.98110+0.00278	train-error:0.07765+0.01049	train-logloss:0.33511+0.01597	test-auc:0.92358+0.02472	test-error:0.12113+0.02122	test-logloss:0.40514+0.02266
# [10]	train-auc:0.98170+0.00225	train-error:0.07897+0.01175	train-logloss:0.31790+0.01615	test-auc:0.92261+0.02140	test-error:0.12111+0.01667	test-logloss:0.39427+0.02252
# [11]	train-auc:0.98276+0.00225	train-error:0.07766+0.01666	train-logloss:0.30203+0.01652	test-auc:0.92476+0.02143	test-error:0.12903+0.02311	test-logloss:0.38296+0.02453
# [12]	train-auc:0.98359+0.00277	train-error:0.07503+0.01417	train-logloss:0.28747+0.01734	test-auc:0.92281+0.02078	test-error:0.13427+0.01980	test-logloss:0.37679+0.02559
# [13]	train-auc:0.98453+0.00310	train-error:0.07503+0.01417	train-logloss:0.27440+0.01736	test-auc:0.92080+0.02089	test-error:0.13427+0.01980	test-logloss:0.37076+0.02662
# [14]	train-auc:0.98523+0.00309	train-error:0.07503+0.01417	train-logloss:0.26242+0.01785	test-auc:0.92198+0.01955	test-error:0.13427+0.01980	test-logloss:0.36635+0.02712
# [15]	train-auc:0.98616+0.00321	train-error:0.07239+0.01232	train-logloss:0.25078+0.01804	test-auc:0.91919+0.02249	test-error:0.13430+0.02378	test-logloss:0.36408+0.03027
# [16]	train-auc:0.98682+0.00268	train-error:0.06844+0.01231	train-logloss:0.24034+0.01806	test-auc:0.91681+0.02120	test-error:0.12640+0.02286	test-logloss:0.36153+0.03014
# [17]	train-auc:0.98775+0.00271	train-error:0.06844+0.01231	train-logloss:0.23110+0.01731	test-auc:0.91525+0.02126	test-error:0.12903+0.02125	test-logloss:0.36051+0.03025
# [18]	train-auc:0.98835+0.00265	train-error:0.06450+0.01312	train-logloss:0.22235+0.01783	test-auc:0.91440+0.02108	test-error:0.12905+0.02660	test-logloss:0.35925+0.03132
# [19]	train-auc:0.98902+0.00264	train-error:0.06318+0.01172	train-logloss:0.21408+0.01729	test-auc:0.91566+0.02296	test-error:0.13167+0.02495	test-logloss:0.35685+0.03297
# [20]	train-auc:0.98948+0.00270	train-error:0.06055+0.01312	train-logloss:0.20647+0.01791	test-auc:0.91297+0.02358	test-error:0.13430+0.02378	test-logloss:0.35892+0.03477
# [21]	train-auc:0.98995+0.00253	train-error:0.05661+0.01532	train-logloss:0.19971+0.01778	test-auc:0.91238+0.02320	test-error:0.13959+0.03105	test-logloss:0.35966+0.03487
# [22]	train-auc:0.99005+0.00273	train-error:0.05661+0.01532	train-logloss:0.19324+0.01794	test-auc:0.91178+0.02377	test-error:0.13959+0.03105	test-logloss:0.36034+0.03490
# [23]	train-auc:0.99035+0.00257	train-error:0.05529+0.01413	train-logloss:0.18712+0.01752	test-auc:0.91102+0.02431	test-error:0.13694+0.02740	test-logloss:0.36157+0.03631
# [24]	train-auc:0.99046+0.00252	train-error:0.05397+0.01350	train-logloss:0.18201+0.01735	test-auc:0.91154+0.02301	test-error:0.13694+0.02740	test-logloss:0.36109+0.03545
# [25]	train-auc:0.99088+0.00227	train-error:0.05397+0.01350	train-logloss:0.17657+0.01702	test-auc:0.90954+0.02294	test-error:0.13696+0.03239	test-logloss:0.36421+0.03580
# [26]	train-auc:0.99146+0.00217	train-error:0.05134+0.01170	train-logloss:0.17110+0.01662	test-auc:0.90760+0.02266	test-error:0.13694+0.02663	test-logloss:0.45954+0.10099
# [27]	train-auc:0.99184+0.00203	train-error:0.05002+0.01349	train-logloss:0.16625+0.01686	test-auc:0.90919+0.02106	test-error:0.13694+0.02663	test-logloss:0.53978+0.22588
# [28]	train-auc:0.99213+0.00211	train-error:0.04739+0.01169	train-logloss:0.16226+0.01675	test-auc:0.90769+0.02158	test-error:0.14219+0.02380	test-logloss:0.54841+0.22008
# Tuned Results:
# train-auc-mean        0.989024
# train-auc-std         0.002644
# train-error-mean      0.063179
# train-error-std       0.011721
# train-logloss-mean    0.214075
# train-logloss-std     0.017285
# test-auc-mean         0.915657
# test-auc-std          0.022962
# test-error-mean       0.131671
# test-error-std        0.024954
# test-logloss-mean     0.356851
# test-logloss-std      0.032975
# Name: 19, dtype: float64

# %%
# Create the grid search object
grid_search_xgboost_model = GridSearchCV(
    xgb_clf, param_grid, cv=5, scoring='neg_log_loss', verbose=5
)

# Fit the model on the training data
grid_search_xgboost_model.fit(X_train, y_train)

# Display the best hyperparameters
print("Best Hyperparameters:", grid_search_xgboost_model.best_params_)

# Get the best model
best_grid_search_xgb_model = grid_search_xgboost_model.best_estimator_

# Evaluate the model with additional metrics
grid_predictions = best_grid_search_xgb_model.predict(X_cv)
print("Accuracy:", accuracy_score(y_cv, grid_predictions))
print("Precision:", precision_score(y_cv, grid_predictions))
print("Recall:", recall_score(y_cv, grid_predictions))
report = classification_report(y_cv,grid_predictions)
print(report)
# Out:
# Fitting 5 folds for each of 1260 candidates, totalling 6300 fits
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.7;, score=-0.438 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.7;, score=-0.451 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.7;, score=-0.434 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.7;, score=-0.433 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.7;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.8;, score=-0.435 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.8;, score=-0.450 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.8;, score=-0.432 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.8;, score=-0.434 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.9;, score=-0.433 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.9;, score=-0.448 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.9;, score=-0.426 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.9;, score=-0.429 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.9;, score=-0.462 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.7;, score=-0.444 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.7;, score=-0.458 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.7;, score=-0.447 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.7;, score=-0.444 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.7;, score=-0.470 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.8;, score=-0.441 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.8;, score=-0.456 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.8;, score=-0.442 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.8;, score=-0.440 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.8;, score=-0.474 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.9;, score=-0.440 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.9;, score=-0.454 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.9;, score=-0.435 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.9;, score=-0.439 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.9;, score=-0.476 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.7;, score=-0.448 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.7;, score=-0.462 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.7;, score=-0.464 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.7;, score=-0.449 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.7;, score=-0.470 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.8;, score=-0.444 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.8;, score=-0.460 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.8;, score=-0.458 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.8;, score=-0.445 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.8;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.9;, score=-0.443 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.9;, score=-0.460 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.9;, score=-0.451 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.9;, score=-0.442 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.9;, score=-0.470 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.7;, score=-0.452 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.7;, score=-0.465 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.7;, score=-0.462 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.7;, score=-0.452 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.7;, score=-0.470 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.8;, score=-0.450 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.8;, score=-0.449 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.8;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.9;, score=-0.449 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.9;, score=-0.464 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.9;, score=-0.458 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.9;, score=-0.447 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.9;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=10, subsample=0.7;, score=-0.455 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=10, subsample=0.7;, score=-0.467 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=10, subsample=0.7;, score=-0.465 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=10, subsample=0.7;, score=-0.458 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=10, subsample=0.7;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=10, subsample=0.8;, score=-0.451 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=10, subsample=0.8;, score=-0.465 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=10, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=10, subsample=0.8;, score=-0.457 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=10, subsample=0.8;, score=-0.466 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=10, subsample=0.9;, score=-0.452 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=10, subsample=0.9;, score=-0.465 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=10, subsample=0.9;, score=-0.459 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=10, subsample=0.9;, score=-0.453 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=3, min_child_weight=10, subsample=0.9;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.7;, score=-0.431 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.7;, score=-0.448 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.7;, score=-0.424 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.7;, score=-0.426 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.7;, score=-0.460 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.8;, score=-0.426 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.8;, score=-0.447 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.8;, score=-0.419 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.8;, score=-0.423 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.8;, score=-0.455 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.9;, score=-0.426 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.9;, score=-0.448 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.9;, score=-0.415 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.9;, score=-0.422 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.9;, score=-0.452 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=3, subsample=0.7;, score=-0.444 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=3, subsample=0.7;, score=-0.458 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=3, subsample=0.7;, score=-0.447 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=3, subsample=0.7;, score=-0.443 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=3, subsample=0.7;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=3, subsample=0.8;, score=-0.439 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=3, subsample=0.8;, score=-0.455 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=3, subsample=0.8;, score=-0.439 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=3, subsample=0.8;, score=-0.440 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=3, subsample=0.8;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=3, subsample=0.9;, score=-0.436 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=3, subsample=0.9;, score=-0.454 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=3, subsample=0.9;, score=-0.434 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=3, subsample=0.9;, score=-0.437 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=3, subsample=0.9;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=5, subsample=0.7;, score=-0.447 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=5, subsample=0.7;, score=-0.462 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=5, subsample=0.7;, score=-0.464 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=5, subsample=0.7;, score=-0.449 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=5, subsample=0.7;, score=-0.470 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=5, subsample=0.8;, score=-0.445 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=5, subsample=0.8;, score=-0.460 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=5, subsample=0.8;, score=-0.458 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=5, subsample=0.8;, score=-0.445 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=5, subsample=0.8;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=5, subsample=0.9;, score=-0.442 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=5, subsample=0.9;, score=-0.459 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=5, subsample=0.9;, score=-0.450 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=5, subsample=0.9;, score=-0.442 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=5, subsample=0.9;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=7, subsample=0.7;, score=-0.452 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=7, subsample=0.7;, score=-0.465 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=7, subsample=0.7;, score=-0.462 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=7, subsample=0.7;, score=-0.452 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=7, subsample=0.7;, score=-0.470 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=7, subsample=0.8;, score=-0.450 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=7, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=7, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=7, subsample=0.8;, score=-0.449 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=7, subsample=0.8;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=7, subsample=0.9;, score=-0.449 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=7, subsample=0.9;, score=-0.464 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=7, subsample=0.9;, score=-0.458 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=7, subsample=0.9;, score=-0.448 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=7, subsample=0.9;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=10, subsample=0.7;, score=-0.455 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=10, subsample=0.7;, score=-0.467 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=10, subsample=0.7;, score=-0.465 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=10, subsample=0.7;, score=-0.458 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=10, subsample=0.7;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=10, subsample=0.8;, score=-0.451 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=10, subsample=0.8;, score=-0.465 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=10, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=10, subsample=0.8;, score=-0.457 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=10, subsample=0.8;, score=-0.466 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=10, subsample=0.9;, score=-0.452 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=10, subsample=0.9;, score=-0.465 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=10, subsample=0.9;, score=-0.459 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=10, subsample=0.9;, score=-0.453 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=5, min_child_weight=10, subsample=0.9;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=1, subsample=0.7;, score=-0.430 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=1, subsample=0.7;, score=-0.447 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=1, subsample=0.7;, score=-0.424 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=1, subsample=0.7;, score=-0.427 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=1, subsample=0.7;, score=-0.460 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=1, subsample=0.8;, score=-0.425 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=1, subsample=0.8;, score=-0.448 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=1, subsample=0.8;, score=-0.419 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=1, subsample=0.8;, score=-0.423 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=1, subsample=0.8;, score=-0.455 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=1, subsample=0.9;, score=-0.425 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=1, subsample=0.9;, score=-0.447 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=1, subsample=0.9;, score=-0.414 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=1, subsample=0.9;, score=-0.424 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=1, subsample=0.9;, score=-0.450 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=3, subsample=0.7;, score=-0.444 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=3, subsample=0.7;, score=-0.458 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=3, subsample=0.7;, score=-0.447 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=3, subsample=0.7;, score=-0.443 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=3, subsample=0.7;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=3, subsample=0.8;, score=-0.439 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=3, subsample=0.8;, score=-0.454 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=3, subsample=0.8;, score=-0.439 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=3, subsample=0.8;, score=-0.440 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=3, subsample=0.8;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=3, subsample=0.9;, score=-0.436 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=3, subsample=0.9;, score=-0.454 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=3, subsample=0.9;, score=-0.435 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=3, subsample=0.9;, score=-0.437 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=3, subsample=0.9;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=5, subsample=0.7;, score=-0.447 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=5, subsample=0.7;, score=-0.462 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=5, subsample=0.7;, score=-0.464 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=5, subsample=0.7;, score=-0.449 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=5, subsample=0.7;, score=-0.470 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=5, subsample=0.8;, score=-0.445 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=5, subsample=0.8;, score=-0.460 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=5, subsample=0.8;, score=-0.458 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=5, subsample=0.8;, score=-0.445 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=5, subsample=0.8;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=5, subsample=0.9;, score=-0.442 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=5, subsample=0.9;, score=-0.459 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=5, subsample=0.9;, score=-0.450 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=5, subsample=0.9;, score=-0.442 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=5, subsample=0.9;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=7, subsample=0.7;, score=-0.452 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=7, subsample=0.7;, score=-0.465 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=7, subsample=0.7;, score=-0.462 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=7, subsample=0.7;, score=-0.452 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=7, subsample=0.7;, score=-0.470 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=7, subsample=0.8;, score=-0.450 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=7, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=7, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=7, subsample=0.8;, score=-0.449 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=7, subsample=0.8;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=7, subsample=0.9;, score=-0.449 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=7, subsample=0.9;, score=-0.464 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=7, subsample=0.9;, score=-0.458 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=7, subsample=0.9;, score=-0.448 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=7, subsample=0.9;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=10, subsample=0.7;, score=-0.455 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=10, subsample=0.7;, score=-0.467 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=10, subsample=0.7;, score=-0.465 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=10, subsample=0.7;, score=-0.458 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=10, subsample=0.7;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=10, subsample=0.8;, score=-0.451 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=10, subsample=0.8;, score=-0.465 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=10, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=10, subsample=0.8;, score=-0.457 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=10, subsample=0.8;, score=-0.466 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=10, subsample=0.9;, score=-0.452 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=10, subsample=0.9;, score=-0.465 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=10, subsample=0.9;, score=-0.459 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=10, subsample=0.9;, score=-0.453 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=7, min_child_weight=10, subsample=0.9;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=1, subsample=0.7;, score=-0.430 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=1, subsample=0.7;, score=-0.447 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=1, subsample=0.7;, score=-0.424 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=1, subsample=0.7;, score=-0.427 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=1, subsample=0.7;, score=-0.460 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=1, subsample=0.8;, score=-0.425 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=1, subsample=0.8;, score=-0.448 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=1, subsample=0.8;, score=-0.419 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=1, subsample=0.8;, score=-0.423 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=1, subsample=0.8;, score=-0.455 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=1, subsample=0.9;, score=-0.424 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=1, subsample=0.9;, score=-0.448 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=1, subsample=0.9;, score=-0.414 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=1, subsample=0.9;, score=-0.424 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=1, subsample=0.9;, score=-0.450 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=3, subsample=0.7;, score=-0.444 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=3, subsample=0.7;, score=-0.458 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=3, subsample=0.7;, score=-0.447 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=3, subsample=0.7;, score=-0.443 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=3, subsample=0.7;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=3, subsample=0.8;, score=-0.439 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=3, subsample=0.8;, score=-0.454 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=3, subsample=0.8;, score=-0.439 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=3, subsample=0.8;, score=-0.440 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=3, subsample=0.8;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=3, subsample=0.9;, score=-0.436 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=3, subsample=0.9;, score=-0.454 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=3, subsample=0.9;, score=-0.435 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=3, subsample=0.9;, score=-0.437 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=3, subsample=0.9;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=5, subsample=0.7;, score=-0.447 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=5, subsample=0.7;, score=-0.462 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=5, subsample=0.7;, score=-0.464 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=5, subsample=0.7;, score=-0.449 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=5, subsample=0.7;, score=-0.470 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=5, subsample=0.8;, score=-0.445 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=5, subsample=0.8;, score=-0.460 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=5, subsample=0.8;, score=-0.458 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=5, subsample=0.8;, score=-0.445 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=5, subsample=0.8;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=5, subsample=0.9;, score=-0.442 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=5, subsample=0.9;, score=-0.459 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=5, subsample=0.9;, score=-0.450 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=5, subsample=0.9;, score=-0.442 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=5, subsample=0.9;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=7, subsample=0.7;, score=-0.452 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=7, subsample=0.7;, score=-0.465 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=7, subsample=0.7;, score=-0.462 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=7, subsample=0.7;, score=-0.452 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=7, subsample=0.7;, score=-0.470 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=7, subsample=0.8;, score=-0.450 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=7, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=7, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=7, subsample=0.8;, score=-0.449 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=7, subsample=0.8;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=7, subsample=0.9;, score=-0.449 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=7, subsample=0.9;, score=-0.464 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=7, subsample=0.9;, score=-0.458 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=7, subsample=0.9;, score=-0.448 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=7, subsample=0.9;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=10, subsample=0.7;, score=-0.455 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=10, subsample=0.7;, score=-0.467 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=10, subsample=0.7;, score=-0.465 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=10, subsample=0.7;, score=-0.458 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=10, subsample=0.7;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=10, subsample=0.8;, score=-0.451 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=10, subsample=0.8;, score=-0.465 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=10, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=10, subsample=0.8;, score=-0.457 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=10, subsample=0.8;, score=-0.466 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=10, subsample=0.9;, score=-0.452 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=10, subsample=0.9;, score=-0.465 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=10, subsample=0.9;, score=-0.459 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=10, subsample=0.9;, score=-0.453 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=9, min_child_weight=10, subsample=0.9;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=1, subsample=0.7;, score=-0.430 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=1, subsample=0.7;, score=-0.447 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=1, subsample=0.7;, score=-0.424 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=1, subsample=0.7;, score=-0.427 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=1, subsample=0.7;, score=-0.460 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=1, subsample=0.8;, score=-0.425 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=1, subsample=0.8;, score=-0.448 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=1, subsample=0.8;, score=-0.419 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=1, subsample=0.8;, score=-0.423 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=1, subsample=0.8;, score=-0.455 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=1, subsample=0.9;, score=-0.424 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=1, subsample=0.9;, score=-0.448 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=1, subsample=0.9;, score=-0.414 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=1, subsample=0.9;, score=-0.424 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=1, subsample=0.9;, score=-0.450 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=3, subsample=0.7;, score=-0.444 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=3, subsample=0.7;, score=-0.458 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=3, subsample=0.7;, score=-0.447 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=3, subsample=0.7;, score=-0.443 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=3, subsample=0.7;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=3, subsample=0.8;, score=-0.439 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=3, subsample=0.8;, score=-0.454 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=3, subsample=0.8;, score=-0.439 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=3, subsample=0.8;, score=-0.440 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=3, subsample=0.8;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=3, subsample=0.9;, score=-0.436 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=3, subsample=0.9;, score=-0.454 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=3, subsample=0.9;, score=-0.435 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=3, subsample=0.9;, score=-0.437 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=3, subsample=0.9;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=5, subsample=0.7;, score=-0.447 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=5, subsample=0.7;, score=-0.462 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=5, subsample=0.7;, score=-0.464 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=5, subsample=0.7;, score=-0.449 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=5, subsample=0.7;, score=-0.470 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=5, subsample=0.8;, score=-0.445 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=5, subsample=0.8;, score=-0.460 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=5, subsample=0.8;, score=-0.458 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=5, subsample=0.8;, score=-0.445 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=5, subsample=0.8;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=5, subsample=0.9;, score=-0.442 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=5, subsample=0.9;, score=-0.459 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=5, subsample=0.9;, score=-0.450 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=5, subsample=0.9;, score=-0.442 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=5, subsample=0.9;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=7, subsample=0.7;, score=-0.452 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=7, subsample=0.7;, score=-0.465 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=7, subsample=0.7;, score=-0.462 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=7, subsample=0.7;, score=-0.452 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=7, subsample=0.7;, score=-0.470 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=7, subsample=0.8;, score=-0.450 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=7, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=7, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=7, subsample=0.8;, score=-0.449 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=7, subsample=0.8;, score=-0.469 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=7, subsample=0.9;, score=-0.449 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=7, subsample=0.9;, score=-0.464 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=7, subsample=0.9;, score=-0.458 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=7, subsample=0.9;, score=-0.448 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=7, subsample=0.9;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=10, subsample=0.7;, score=-0.455 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=10, subsample=0.7;, score=-0.467 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=10, subsample=0.7;, score=-0.465 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=10, subsample=0.7;, score=-0.458 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=10, subsample=0.7;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=10, subsample=0.8;, score=-0.451 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=10, subsample=0.8;, score=-0.465 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=10, subsample=0.8;, score=-0.464 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=10, subsample=0.8;, score=-0.457 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=10, subsample=0.8;, score=-0.466 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=10, subsample=0.9;, score=-0.452 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=10, subsample=0.9;, score=-0.465 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=10, subsample=0.9;, score=-0.459 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=10, subsample=0.9;, score=-0.453 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.7, eta=0.01, max_depth=11, min_child_weight=10, subsample=0.9;, score=-0.468 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.7, eta=0.01, max_depth=15, min_child_weight=1, subsample=0.7;, score=-0.430 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.7, eta=0.01, max_depth=15, min_child_weight=1, subsample=0.7;, score=-0.447 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.7, eta=0.01, max_depth=15, min_child_weight=1, subsample=0.7;, score=-0.424 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.7, eta=0.01, max_depth=15, min_child_weight=1, subsample=0.7;, score=-0.427 total time=   0.0s
# ...
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=3, subsample=0.9;, score=-0.425 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=3, subsample=0.9;, score=-0.419 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=5, subsample=0.7;, score=-0.321 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=5, subsample=0.7;, score=-0.449 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=5, subsample=0.7;, score=-0.340 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=5, subsample=0.7;, score=-0.344 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=5, subsample=0.7;, score=-0.405 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=5, subsample=0.8;, score=-0.373 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=5, subsample=0.8;, score=-0.447 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=5, subsample=0.8;, score=-0.360 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=5, subsample=0.8;, score=-0.369 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=5, subsample=0.8;, score=-0.392 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=5, subsample=0.9;, score=-0.334 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=5, subsample=0.9;, score=-0.445 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=5, subsample=0.9;, score=-0.327 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=5, subsample=0.9;, score=-0.381 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=5, subsample=0.9;, score=-0.388 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=7, subsample=0.7;, score=-0.349 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=7, subsample=0.7;, score=-0.438 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=7, subsample=0.7;, score=-0.332 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=7, subsample=0.7;, score=-0.313 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=7, subsample=0.7;, score=-0.399 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=7, subsample=0.8;, score=-0.348 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=7, subsample=0.8;, score=-0.409 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=7, subsample=0.8;, score=-0.356 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=7, subsample=0.8;, score=-0.326 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=7, subsample=0.8;, score=-0.407 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=7, subsample=0.9;, score=-0.344 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=7, subsample=0.9;, score=-0.439 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=7, subsample=0.9;, score=-0.344 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=7, subsample=0.9;, score=-0.357 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=7, subsample=0.9;, score=-0.413 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=10, subsample=0.7;, score=-0.374 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=10, subsample=0.7;, score=-0.473 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=10, subsample=0.7;, score=-0.378 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=10, subsample=0.7;, score=-0.345 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=10, subsample=0.7;, score=-0.424 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=10, subsample=0.8;, score=-0.365 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=10, subsample=0.8;, score=-0.476 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=10, subsample=0.8;, score=-0.394 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=10, subsample=0.8;, score=-0.339 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=10, subsample=0.8;, score=-0.421 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=10, subsample=0.9;, score=-0.369 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=10, subsample=0.9;, score=-0.411 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=10, subsample=0.9;, score=-0.380 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=10, subsample=0.9;, score=-0.323 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=15, min_child_weight=10, subsample=0.9;, score=-0.415 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=1, subsample=0.7;, score=-0.491 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=1, subsample=0.7;, score=-0.616 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=1, subsample=0.7;, score=-0.325 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=1, subsample=0.7;, score=-0.458 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=1, subsample=0.7;, score=-0.531 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=1, subsample=0.8;, score=-0.474 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=1, subsample=0.8;, score=-0.647 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=1, subsample=0.8;, score=-0.410 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=1, subsample=0.8;, score=-0.478 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=1, subsample=0.8;, score=-0.579 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=1, subsample=0.9;, score=-0.479 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=1, subsample=0.9;, score=-0.573 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=1, subsample=0.9;, score=-0.399 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=1, subsample=0.9;, score=-0.513 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=1, subsample=0.9;, score=-0.539 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=3, subsample=0.7;, score=-0.380 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=3, subsample=0.7;, score=-0.539 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=3, subsample=0.7;, score=-0.285 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=3, subsample=0.7;, score=-0.424 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=3, subsample=0.7;, score=-0.409 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=3, subsample=0.8;, score=-0.344 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=3, subsample=0.8;, score=-0.504 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=3, subsample=0.8;, score=-0.304 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=3, subsample=0.8;, score=-0.460 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=3, subsample=0.8;, score=-0.423 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=3, subsample=0.9;, score=-0.371 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=3, subsample=0.9;, score=-0.467 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=3, subsample=0.9;, score=-0.324 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=3, subsample=0.9;, score=-0.425 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=3, subsample=0.9;, score=-0.419 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=5, subsample=0.7;, score=-0.321 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=5, subsample=0.7;, score=-0.449 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=5, subsample=0.7;, score=-0.340 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=5, subsample=0.7;, score=-0.344 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=5, subsample=0.7;, score=-0.405 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=5, subsample=0.8;, score=-0.373 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=5, subsample=0.8;, score=-0.447 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=5, subsample=0.8;, score=-0.360 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=5, subsample=0.8;, score=-0.369 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=5, subsample=0.8;, score=-0.392 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=5, subsample=0.9;, score=-0.334 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=5, subsample=0.9;, score=-0.445 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=5, subsample=0.9;, score=-0.327 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=5, subsample=0.9;, score=-0.381 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=5, subsample=0.9;, score=-0.388 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=7, subsample=0.7;, score=-0.349 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=7, subsample=0.7;, score=-0.438 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=7, subsample=0.7;, score=-0.332 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=7, subsample=0.7;, score=-0.313 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=7, subsample=0.7;, score=-0.399 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=7, subsample=0.8;, score=-0.348 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=7, subsample=0.8;, score=-0.409 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=7, subsample=0.8;, score=-0.356 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=7, subsample=0.8;, score=-0.326 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=7, subsample=0.8;, score=-0.407 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=7, subsample=0.9;, score=-0.344 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=7, subsample=0.9;, score=-0.439 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=7, subsample=0.9;, score=-0.344 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=7, subsample=0.9;, score=-0.357 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=7, subsample=0.9;, score=-0.413 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=10, subsample=0.7;, score=-0.374 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=10, subsample=0.7;, score=-0.473 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=10, subsample=0.7;, score=-0.378 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=10, subsample=0.7;, score=-0.345 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=10, subsample=0.7;, score=-0.424 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=10, subsample=0.8;, score=-0.365 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=10, subsample=0.8;, score=-0.476 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=10, subsample=0.8;, score=-0.394 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=10, subsample=0.8;, score=-0.339 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=10, subsample=0.8;, score=-0.421 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=10, subsample=0.9;, score=-0.369 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=10, subsample=0.9;, score=-0.411 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=10, subsample=0.9;, score=-0.380 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=10, subsample=0.9;, score=-0.323 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.9, eta=0.5, max_depth=20, min_child_weight=10, subsample=0.9;, score=-0.415 total time=   0.0s
# Best Hyperparameters: {'colsample_bytree': 0.7, 'eta': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.7}
# Accuracy: 0.8780487804878049
# Precision: 0.9142857142857143
# Recall: 0.8205128205128205
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.93      0.89        43
#          1.0       0.91      0.82      0.86        39
#
#     accuracy                           0.88        82
#    macro avg       0.88      0.88      0.88        82
# weighted avg       0.88      0.88      0.88        82

# %%
# Get the best parameters from  grid search
best_params = grid_search_xgboost_model.best_params_

# Re-run XGBoost CV with early stopping and additional metrics
xgb_grid_search_tuned_results = xgb.cv(
    best_params, dtrain_clf,
    num_boost_round=1000,
    nfold=5,
    early_stopping_rounds=10,
    metrics=["logloss", "auc", "error"],
    verbose_eval=True
)

# Display tuned results
print("Tuned Results:")
print(xgb_grid_search_tuned_results.iloc[-1])
# Out:
# [0]	train-logloss:0.63440+0.00236	train-auc:0.91648+0.00945	train-error:0.30263+0.12759	test-logloss:0.64000+0.00511	test-auc:0.90666+0.02056	test-error:0.32632+0.14732
# [1]	train-logloss:0.58632+0.00295	train-auc:0.92770+0.00829	train-error:0.13026+0.00967	test-logloss:0.59717+0.00784	test-auc:0.91233+0.02173	test-error:0.15263+0.02440
# [2]	train-logloss:0.54668+0.00461	train-auc:0.93293+0.00607	train-error:0.12763+0.01184	test-logloss:0.56017+0.00914	test-auc:0.91801+0.02154	test-error:0.14474+0.01177
# [3]	train-logloss:0.51201+0.00675	train-auc:0.93494+0.00592	train-error:0.12566+0.01069	test-logloss:0.52774+0.00905	test-auc:0.91839+0.02135	test-error:0.14211+0.00985
# [4]	train-logloss:0.48290+0.00769	train-auc:0.94002+0.00483	train-error:0.12171+0.01213	test-logloss:0.50162+0.00905	test-auc:0.91897+0.01606	test-error:0.14474+0.01177
# [5]	train-logloss:0.45887+0.00842	train-auc:0.94039+0.00487	train-error:0.12039+0.00738	test-logloss:0.48045+0.01194	test-auc:0.92006+0.01552	test-error:0.14211+0.01534
# [6]	train-logloss:0.44082+0.00903	train-auc:0.94351+0.00500	train-error:0.11842+0.00721	test-logloss:0.46563+0.01050	test-auc:0.92027+0.01278	test-error:0.14474+0.02354
# [7]	train-logloss:0.42420+0.00916	train-auc:0.94693+0.00577	train-error:0.11974+0.00574	test-logloss:0.45265+0.01020	test-auc:0.91930+0.01148	test-error:0.14474+0.01861
# [8]	train-logloss:0.40604+0.01013	train-auc:0.94775+0.00593	train-error:0.11908+0.00566	test-logloss:0.43689+0.00910	test-auc:0.91932+0.01226	test-error:0.14211+0.01534
# [9]	train-logloss:0.38990+0.00959	train-auc:0.95055+0.00389	train-error:0.11645+0.00795	test-logloss:0.42385+0.00962	test-auc:0.92232+0.01181	test-error:0.13684+0.01342
# [10]	train-logloss:0.37586+0.01002	train-auc:0.95174+0.00394	train-error:0.11447+0.00962	test-logloss:0.41324+0.00957	test-auc:0.92248+0.01119	test-error:0.13421+0.00985
# [11]	train-logloss:0.36365+0.00988	train-auc:0.95222+0.00362	train-error:0.11184+0.00658	test-logloss:0.40417+0.01202	test-auc:0.92156+0.01670	test-error:0.13421+0.00985
# [12]	train-logloss:0.35312+0.01050	train-auc:0.95259+0.00403	train-error:0.11118+0.00638	test-logloss:0.39647+0.01424	test-auc:0.92190+0.01697	test-error:0.14211+0.01746
# [13]	train-logloss:0.34302+0.01066	train-auc:0.95299+0.00388	train-error:0.10987+0.00677	test-logloss:0.38869+0.01639	test-auc:0.92063+0.01816	test-error:0.14211+0.01934
# [14]	train-logloss:0.33415+0.01031	train-auc:0.95351+0.00419	train-error:0.10921+0.00671	test-logloss:0.38307+0.01725	test-auc:0.92075+0.01787	test-error:0.14211+0.01934
# [15]	train-logloss:0.32582+0.01073	train-auc:0.95454+0.00405	train-error:0.10921+0.00671	test-logloss:0.37732+0.01823	test-auc:0.92062+0.01545	test-error:0.13947+0.01785
# [16]	train-logloss:0.31777+0.01102	train-auc:0.95616+0.00457	train-error:0.10855+0.00721	test-logloss:0.37087+0.02011	test-auc:0.92149+0.01649	test-error:0.13947+0.01785
# [17]	train-logloss:0.31156+0.01192	train-auc:0.95740+0.00481	train-error:0.10592+0.00816	test-logloss:0.36775+0.02076	test-auc:0.92143+0.01484	test-error:0.13947+0.01785
# [18]	train-logloss:0.30575+0.01179	train-auc:0.95808+0.00480	train-error:0.10592+0.00816	test-logloss:0.36724+0.02272	test-auc:0.91701+0.01624	test-error:0.13684+0.01969
# [19]	train-logloss:0.30090+0.01198	train-auc:0.95896+0.00479	train-error:0.10461+0.00789	test-logloss:0.36393+0.02230	test-auc:0.91752+0.01660	test-error:0.13947+0.01785
# [20]	train-logloss:0.29544+0.01174	train-auc:0.95962+0.00466	train-error:0.10461+0.00638	test-logloss:0.35854+0.02371	test-auc:0.91862+0.01725	test-error:0.13947+0.01785
# Tuned Results:
# train-logloss-mean    0.375861
# train-logloss-std     0.010020
# train-auc-mean        0.951743
# train-auc-std         0.003936
# train-error-mean      0.114474
# train-error-std       0.009624
# test-logloss-mean     0.413238
# test-logloss-std      0.009571
# test-auc-mean         0.922481
# test-auc-std          0.011193
# test-error-mean       0.134211
# test-error-std        0.009846
# Name: 10, dtype: float64
